# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"../data/attrition_data.csv")
df=df.replace({'STATUS': {'T': 1, 'A': 0}})

# %%
df['REFERRAL_SOURCE'].fillna(value='Unknown', inplace=True) # This fills all the null values in the columns with 0.

# %%
x=df.drop(['STATUS'], axis=1)
y=df['STATUS']

# %%
label_encoder = LabelEncoder()
for column in x.columns:
    x[column] = label_encoder.fit_transform(x[column])

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(x.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":8})

# %%
df=pd.read_csv(r"../data/attrition_data_with_calculated_columns.csv")
df=df.replace({'STATUS': {'T': 1, 'A': 0}})

# %%
df['REFERRAL_SOURCE'].fillna(value='Unknown', inplace=True) # This fills all the null values in the columns with 0.

# %%
x=df.drop(['STATUS'], axis=1)
y=df['STATUS']

# %%
label_encoder = LabelEncoder()
for column in x.columns:
    x[column] = label_encoder.fit_transform(x[column])

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(x.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":7})
